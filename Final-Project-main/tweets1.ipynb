# %%
import pandas as pd
df=pd.read_csv("TweetsThree.csv")
df.head()
# Out:
#    Unnamed: 0                   id  \
# 0           0  1514444290008629251
# 1           1  1514444286716174348
# 2           2  1514444285915004930
# 3           3  1514444277094690820
# 4           4  1514444273655382028
#
#                                           tweet_text  \
# 0  @Lakers @hornets start discussing the westbroo...
# 1  Valke vs. Hornets score, takeaways: Atlanta pe...
# 2  @TheHoopCentral it will be best for both parti...
# 3           RT @62PointCurry: hornets went out sad 💀
# 4  RT @TUSidelines: Shenendehowa graduate Kevin H...
#
#                   created_at                 source  \
# 0  2022-04-14 03:23:50+00:00     Twitter for iPhone
# 1  2022-04-14 03:23:49+00:00          WordPress.com
# 2  2022-04-14 03:23:49+00:00     Twitter for iPhone
# 3  2022-04-14 03:23:47+00:00        Stephen Are Cat
# 4  2022-04-14 03:23:46+00:00  ZTTwitterStreamingApp
#
#                                       public_metrics language  retweet_count  \
# ...

# %%
top_tweets = df[(df["retweet_count"] > 400) & (df["like_count"] > 400)]
print(len(top_tweets))
top_tweets.head()
# Out:
# 3
#        Unnamed: 0                   id  \
# 18745       18745  1514406478840582151
# 22329       22329  1514397833369112578
# 40729       40729  1514246487978524673
#
#                                               tweet_text  \
# 18745  All the charlotte hornets roster do is make mu...
# 22329  The Hornets really had to walk to the arena fo...
# 40729  Miles Bridges is expected to command a maximum...
#
#                       created_at                source  \
# 18745  2022-04-14 00:53:35+00:00    Twitter for iPhone
# 22329  2022-04-14 00:19:14+00:00  Twitter Media Studio
# 40729  2022-04-13 14:17:50+00:00    Twitter for iPhone
#
#                                           public_metrics language  \
# 18745  {'retweet_count': 538, 'reply_count': 33, 'lik...       en
# 22329  {'retweet_count': 410, 'reply_count': 154, 'li...       en
# 40729  {'retweet_count': 769, 'reply_count': 639, 'li...       en
#
#        retweet_count  reply_count  like_count  quote_count
# ...
